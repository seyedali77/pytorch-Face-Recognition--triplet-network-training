# %% [markdown]
# <div class="alert alert-success">
#     <h1 align="center">Face Recognition (Triplet Loss)</h1>
#     <h3 align="center">Seyed Ali Abolfazli</a></h3>
# </div>

# %% [markdown]
# ## Introduction

# %% [markdown]
# <h6>Face Recognition:</h6>
#  - Many classes, but very few examples for each class.

# %% [markdown]
# ## Topics

# %% [markdown]
# - Face Recognition
# - Siamese Network
# - Triplet loss and Contrastive loss
# - Defining and implementing our Dataset class.

# %% [markdown]
# ## Libraries

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import os
import sys
import random
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import torchvision
import torchvision.utils
import torchvision.models as models
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset

from data_utils import create_validation_data

use_gpu = torch.cuda.is_available()

# %% [markdown]
# Helper methods

# %%
def get_model(model_name, pretrained=True):
    return models.__dict__[model_name](pretrained)


def imshow(img, text=None):
    img_np = img.numpy().transpose((1, 2, 0))
    plt.axis("off")
    if text:
        plt.text(175, 8, text, style='italic', fontweight='bold',
                 bbox={'facecolor': 'white', 'alpha': 0.8, 'pad': 10})
    plt.imshow(img_np)
    plt.show()

# %% [markdown]
# ## Data

# %% [markdown]
# Here, we will use [Cambridge AT&T Face Dataset](https://www.kaggle.com/kasikrit/att-database-of-faces).
# - It contains images from 40 different persons.
# - For each person, there are 10 different images.

# %% [markdown]
# <img src='imgs/ATT_Face_Dataset-4rows.png' width='80%'/>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !apt-get install unrar
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unrar is already the newest version (1:6.1.5-1).
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.

# %%
# !unrar x "/content/drive/My Drive/att_faces.rar" /content/att_faces/
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/drive/My Drive/att_faces.rar
#
# Creating    /content/att_faces                                        OK
# Creating    /content/att_faces/att_faces                              OK
#   OK
# Creating    /content/att_faces/att_faces/train                        OK
# Creating    /content/att_faces/att_faces/train/s1                     OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s10                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s11                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s12                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s13                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s14                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s15                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s16                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s17                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s18                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s19                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s2                     OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s20                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s21                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s22                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s23                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s24                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s25                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s26                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s27                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s28                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s29                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s3                     OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s30                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s31                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s32                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s33                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s34                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s35                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s36                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s37                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s38                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s39                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s4                     OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s40                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s5                     OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s6                     OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s7                     OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s8                     OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/train/s9                     OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid                        OK
# Creating    /content/att_faces/att_faces/valid/s1                     OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s10                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s11                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s12                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s13                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s14                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s15                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s16                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s17                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s18                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s19                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s2                     OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s20                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s21                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s22                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s23                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s24                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s25                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s26                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s27                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s28                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s29                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s3                     OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s30                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s31                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s32                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s33                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s34                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s35                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s36                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s37                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s38                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s39                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s4                     OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s40                    OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s5                     OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s6                     OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s7                     OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s8                     OK
#   OK
#   OK
# Creating    /content/att_faces/att_faces/valid/s9                     OK
#   OK
#   OK
# All OK

# %%
DATA_DIR = '/content/MyDrive/att_faces/att_faces/'
if os.path.exists(DATA_DIR):
    print("Files extracted:")
    print(os.listdir(DATA_DIR))
else:
    print("Extraction failed.")
# Out:
# Extraction failed.

# %%
DATA_DIR = '/content/att_faces/att_faces/'
train_dir = f'{DATA_DIR}train'
valid_dir = f'{DATA_DIR}valid'

sz = 96
batch_size = 16
embed_size = 128
num_epochs = 10

cnn_name = 'resnet152'

# %%
os.listdir(DATA_DIR)
# Out:
# ['train', 'valid', 'README']

# %%
# make validation dataset
if not os.path.exists(valid_dir):
    create_validation_data(train_dir, valid_dir, split=0.20, ext='jpg')

# %% [markdown]
# ### Dataset

# %%
class TripletNetworkDataset(Dataset):

    def __init__(self, imgs, transform=None):
        self.imgs = imgs
        self.transform = transform or transforms.ToTensor()

    def __getitem__(self, index):
        # Select anchor image and its label from dataset
        anchor, anchor_label = self.imgs[index]

        # Randomly select a positive and a negative example
        positive = random.choice([img for img, lbl in self.imgs if lbl == anchor_label])
        negative = random.choice([img for img, lbl in self.imgs if lbl != anchor_label])

        # read the images (anchor, positive and negative images)
        anc_img = Image.open(anchor).convert('RGB')
        pos_img = Image.open(positive).convert('RGB')
        neg_img = Image.open(negative).convert('RGB')

        # perform any required transformation (if any)
        if self.transform is not None:
            anc_img = self.transform(anc_img)
            pos_img = self.transform(pos_img)
            neg_img = self.transform(neg_img)

        return anc_img, pos_img, neg_img

    def __len__(self):
        return len(self.imgs)

# %% [markdown]
# #### Training data

# %%
zoom = int((1.0 + random.random() / 10.0) * sz)  # up to 10 percent zoom

tfms = transforms.Compose([
    transforms.Resize((zoom, zoom)),
    transforms.RandomCrop(sz),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(5),
    transforms.ToTensor()
])

face_dataset = datasets.ImageFolder(train_dir)
train_ds = TripletNetworkDataset(face_dataset.imgs, transform=tfms)
train_dl = DataLoader(train_ds, batch_size=8, shuffle=True, num_workers=0)

# %% [markdown]
# #### Validation data

# %%
valid_tfms = transforms.Compose([
    transforms.Resize((zoom, zoom)),
    transforms.ToTensor()
])

valid_face_dataset = datasets.ImageFolder(valid_dir)
valid_ds = TripletNetworkDataset(valid_face_dataset.imgs, transform=valid_tfms)
valid_dl = DataLoader(valid_ds, batch_size=batch_size, shuffle=False, num_workers=0)

# %% [markdown]
# ### Visualize dataset

# %%
anch_imgs, pos_imgs, neg_imgs = next(iter(train_dl))
concat = torch.cat((anch_imgs, pos_imgs, neg_imgs), 0)
plt.figure(figsize=(24, 9))
imshow(torchvision.utils.make_grid(concat, nrow=8))

# %% [markdown]
# ## Model: Triplet Netwok

# %%
class TripletNetwork(nn.Module):

    def __init__(self, model, embed_size):
        super(TripletNetwork, self).__init__()
        num_features = model.fc.in_features
        model.fc = nn.Sequential(
            nn.Linear(num_features, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),
            nn.Linear(512, embed_size))
        self.model = model

    def forward(self, anc, pos, neg):
        f_anc = self.model(anc)
        f_pos = self.model(pos)
        f_neg = self.model(neg)
        return f_anc, f_pos, f_neg

# %% [markdown]
# ## Loss: Triplet Loss
# Given a triplet $(a, p, n)$, the loss is defined as following:

# %% [markdown]
# $$L(a, p, n) = \max (\lVert f(a) - f(p) \rVert^2 - \lVert f(a) - f(n) \rVert^2 + \alpha, 0)$$
#
# In wich:
# - $a$ is the anchor image
# - $p$ is the positive example, and
# - $n$ is the negative example.
#
# Also, $f(.)$ is the vector of features extracted from a CNN (i.e., embedding vector).

# %%
class TripletLoss(nn.Module):

    def __init__(self, margin=0.2):
        super(TripletLoss, self).__init__()
        self.margin = margin

    def forward(self, f_anc, f_pos, f_neg):
        pos_distance = F.pairwise_distance(f_anc, f_pos)
        neg_distance = F.pairwise_distance(f_anc, f_neg)
        loss = torch.sum(torch.clamp(torch.pow(pos_distance, 2) - \
                                     torch.pow(neg_distance, 2) + self.margin, min=0))
        return loss

# %% [markdown]
# ## Train

# %%
def train_step(model, train_dl, criterion, optimizer, device):
    model.train()

    N = len(train_dl.dataset)
    steps = N // train_dl.batch_size
    avg_loss = 0.0

    for i, (anc, pos, neg) in enumerate(train_dl):
        anc, pos, neg = anc.to(device), pos.to(device), neg.to(device)

        # forward
        f_anc, f_pos, f_neg = model(anc, pos, neg)

        # loss
        loss = criterion(f_anc, f_pos, f_neg)
        avg_loss = (avg_loss * i + loss.item()) / (i + 1)

        # backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # report
        sys.stdout.flush()
        sys.stdout.write("\r Training Step [{:2d}/{:2d}]: loss {:.5f}  ".format(i+1, steps, avg_loss))

    print()

    return model, avg_loss


def validate_step(model, valid_dl, criterion, device):
    model.eval()

    N = len(valid_dl.dataset)
    steps = N // valid_dl.batch_size
    avg_loss = 0.0

    with torch.no_grad():
        for i, (anc, pos, neg) in enumerate(valid_dl):
            anc, pos, neg = anc.to(device), pos.to(device), neg.to(device)

            f_anc, f_pos, f_neg = model(anc, pos, neg)
            loss = criterion(f_anc, f_pos, f_neg)
            avg_loss = (avg_loss * i + loss.item()) / (i + 1)

            # report
            sys.stdout.flush()
            sys.stdout.write("\r Validation Step [{:2d}/{:2d}]: loss {:.5f}  ".format(i+1, steps, avg_loss))
    print()

    return avg_loss


def train(model, train_dl, valid_dl, criterion, optimizer, device, scheduler=None, num_epochs=10):
    best_loss = float('inf')
    best_weights = model.state_dict().copy()

    train_loss_history, valid_loss_history = [], []

    for epoch in range(num_epochs):
        print(f'Epoch {epoch + 1}\n--------')

        model, train_loss = train_step(model, train_dl, criterion, optimizer, device)
        valid_loss = validate_step(model, valid_dl, criterion, device)
        if scheduler:
            scheduler.step()

        train_loss_history.append(train_loss)
        valid_loss_history.append(valid_loss)

        if valid_loss < best_loss:
            best_loss = valid_loss
            best_weights = model.state_dict().copy()
        print()
    loss_history = (train_loss_history, valid_loss_history)
    model.load_state_dict(best_weights)
    return model, best_weights, loss_history

# %%
# data
train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True,  num_workers=0)
valid_dl = DataLoader(valid_ds, batch_size=batch_size, shuffle=False, num_workers=0)

# model
cnn = get_model(cnn_name)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = TripletNetwork(cnn, embed_size).to(device)

# loss and optimizer
criterion = TripletLoss().to(device)
optimizer = optim.Adam(model.parameters(), lr=0.0002)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:135: UserWarning: Using 'weights' as positional parameter(s) is deprecated since 0.13 and may be removed in the future. Please use keyword parameter(s) instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet152-394f9c45.pth" to /root/.cache/torch/hub/checkpoints/resnet152-394f9c45.pth
# 100%|██████████| 230M/230M [00:01<00:00, 145MB/s]

# %% [markdown]
# ## Training

# %%
model, best_weights, loss_hist = train(model,
                                       train_dl, valid_dl,
                                       criterion, optimizer,
                                       device,
                                       scheduler,
                                       num_epochs=num_epochs)
# Out:
# Epoch 1
# --------
#  Training Step [20/20]: loss 19.94497
#  Validation Step [ 5/ 5]: loss 0.22851
#
# Epoch 2
# --------
#  Training Step [20/20]: loss 12.53932
#  Validation Step [ 5/ 5]: loss 1.46346
#
# Epoch 3
# --------
#  Training Step [20/20]: loss 14.03065
#  Validation Step [ 5/ 5]: loss 9.82102
#
# Epoch 4
# --------
#  Training Step [20/20]: loss 18.02241
#  Validation Step [ 5/ 5]: loss 0.91823
#
# Epoch 5
# --------
#  Training Step [20/20]: loss 12.10413
#  Validation Step [ 5/ 5]: loss 1.30548
#
# Epoch 6
# --------
#  Training Step [20/20]: loss 14.42725
#  Validation Step [ 5/ 5]: loss 10.56828
#
# Epoch 7
# --------
#  Training Step [20/20]: loss 9.43677
#  Validation Step [ 5/ 5]: loss 0.26779
#
# Epoch 8
# --------
#  Training Step [20/20]: loss 2.72101
#  Validation Step [ 5/ 5]: loss 0.69298
#
# Epoch 9
# --------
#  Training Step [20/20]: loss 4.72812
#  Validation Step [ 5/ 5]: loss 0.18926
#
# Epoch 10
# --------
#  Training Step [20/20]: loss 1.24167
#  Validation Step [ 5/ 5]: loss 0.95360

# %%
plt.figure(figsize=(12, 4))
plt.plot(loss_hist[0], 'g', label='Training loss')
plt.plot(loss_hist[1], 'r', label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Training and Validation Loss");

# %% [markdown]
# ## Testing

# %%
valid_dl = DataLoader(valid_ds, batch_size=1, shuffle=True)

# %%
model.eval()

dataiter = iter(valid_dl)

with torch.no_grad():
    for i in range(20):
        x0, x1, x2 = next(dataiter)
        concat = torch.cat((x0, x1, x2), 0)
        f0, f1, f2 = model(x0.to(device), x1.to(device), x2.to(device))
        pos_distance = F.pairwise_distance(f0, f1)
        neg_distance = F.pairwise_distance(f0, f2)
        imshow(torchvision.utils.make_grid(concat), f'Dissimilarities: ({pos_distance.item():.2f}, {neg_distance.item():.2f})')
